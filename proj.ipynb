# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('list.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
tables
# Out:
# [('bmw_cars',), ('cars',)]

# %%
# cursor.execute("ALTER TABLE bmw_cars RENAME TO cars;")

# %%
query = 'select * from cars'
df = pd.read_sql_query(query, conn)
df
# Out:
#         id              car_model  year_of_production  engine_volume  \
# 0        0  Mercedes-Benz A-Класс                2002            1.4
# 1        1             Opel Astra                2000            1.6
# 2        2     Mitsubishi Carisma                1999            1.8
# 3        3           Daewoo Matiz                1999            0.8
# 4        4                Audi A6                2002            2.4
# ...    ...                    ...                 ...            ...
# 1935  1935           Daewoo Matiz                2001            0.8
# 1936  1936  ВАЗ (Lada) 2121 (4x4)                2007            1.7
# 1937  1937            Opel Zafira                2003            1.8
# 1938  1938       Volkswagen Jetta                1988            1.8
# 1939  1939              Mazda 626                1989            2.0
#
#        mileage     fuel steering_wheel_location        color  \
# 0     380000.0   бензин              руль слева  серебристый
# 1     200000.0   бензин              руль слева  серебристый
# 2     404123.0   бензин              руль слева        синий
# 3     192600.0   бензин              руль слева  серебристый
# 4     366725.0   бензин              руль слева  серебристый
# ...        ...      ...                     ...          ...
# 1935  190400.0   бензин              руль слева      зеленый
# 1936  111000.0   бензин              руль слева        синий
# 1937  346246.0   бензин              руль слева  серебристый
# 1938  250000.0   бензин              руль слева      голубой
# 1939  250000.0   бензин              руль слева      красный
#
#               body_type     location  price_in_usd
# 0         хэтчбек 5 дв.      Сокулук          4075
# 1             универсал  Джалал-Абад          4420
# 2                 седан  Джалал-Абад        210000
# 3         хэтчбек 5 дв.    Кызыл-Кия          1607
# 4                 седан       Бишкек          4821
# ...                 ...          ...           ...
# 1935      хэтчбек 5 дв.     Кара-Суу          2181
# 1936  внедорожник 3 дв.  Джалал-Абад          3329
# 1937         компактвэн       Ноокат          5166
# 1938              седан       Токмок          1263
# 1939          универсал       Токмок          1378
#
# [1940 rows x 11 columns]

# %%
dt = pd.read_sql_query(query,conn)
dt
# Out:
#         id              car_model  year_of_production  engine_volume  \
# 0        0  Mercedes-Benz A-Класс                2002            1.4
# 1        1             Opel Astra                2000            1.6
# 2        2     Mitsubishi Carisma                1999            1.8
# 3        3           Daewoo Matiz                1999            0.8
# 4        4                Audi A6                2002            2.4
# ...    ...                    ...                 ...            ...
# 1935  1935           Daewoo Matiz                2001            0.8
# 1936  1936  ВАЗ (Lada) 2121 (4x4)                2007            1.7
# 1937  1937            Opel Zafira                2003            1.8
# 1938  1938       Volkswagen Jetta                1988            1.8
# 1939  1939              Mazda 626                1989            2.0
#
#        mileage     fuel steering_wheel_location        color  \
# 0     380000.0   бензин              руль слева  серебристый
# 1     200000.0   бензин              руль слева  серебристый
# 2     404123.0   бензин              руль слева        синий
# 3     192600.0   бензин              руль слева  серебристый
# 4     366725.0   бензин              руль слева  серебристый
# ...        ...      ...                     ...          ...
# 1935  190400.0   бензин              руль слева      зеленый
# 1936  111000.0   бензин              руль слева        синий
# 1937  346246.0   бензин              руль слева  серебристый
# 1938  250000.0   бензин              руль слева      голубой
# 1939  250000.0   бензин              руль слева      красный
#
#               body_type     location  price_in_usd
# 0         хэтчбек 5 дв.      Сокулук          4075
# 1             универсал  Джалал-Абад          4420
# 2                 седан  Джалал-Абад        210000
# 3         хэтчбек 5 дв.    Кызыл-Кия          1607
# 4                 седан       Бишкек          4821
# ...                 ...          ...           ...
# 1935      хэтчбек 5 дв.     Кара-Суу          2181
# 1936  внедорожник 3 дв.  Джалал-Абад          3329
# 1937         компактвэн       Ноокат          5166
# 1938              седан       Токмок          1263
# 1939          универсал       Токмок          1378
#
# [1940 rows x 11 columns]
